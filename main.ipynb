# %%
# !cd garbageClassifier-master && python test_se.py
# Out:
# 测试数据集大小: 20
# 类别: ['cardborad', 'cell', 'cigarerre', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     11.jpg                         cardborad       cardborad       ✓
# 2     220.jpg                        cardborad       cigarerre       ✗
# 3     tmp291.png                     cell            power_bank      ✗
# 4     tmp663.jpg                     cell            pericarp        ✗
# 5     tmp6634.jpg                    cell            cell            ✓
# 6     tmp445A.jpg                    cigarerre       cigarerre       ✓
# 7     tmp8027.jpg                    cigarerre       cardborad       ✗
# 8     tmp7F8D.png                    glass           pericarp        ✗
# 9     tmpC6C8.png                    glass           plastic         ✗
# 10    tmp4549.png                    leftovers       leftovers       ✓
# ...

# %%
# !cd garbageClassifier-master && python test_se.py
# Out:
# 测试数据集大小: 20
# 类别: ['cardborad', 'cell', 'cigarerre', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     11.jpg                         cardborad       power_bank      ✗
# 2     220.jpg                        cardborad       power_bank      ✗
# 3     tmp291.png                     cell            plastic         ✗
# 4     tmp663.jpg                     cell            power_bank      ✗
# 5     tmp6634.jpg                    cell            power_bank      ✗
# 6     tmp445A.jpg                    cigarerre       power_bank      ✗
# 7     tmp8027.jpg                    cigarerre       power_bank      ✗
# 8     tmp7F8D.png                    glass           glass           ✓
# 9     tmpC6C8.png                    glass           power_bank      ✗
# 10    tmp4549.png                    leftovers       plastic         ✗
# ...

# %%
# !cd garbageClassifier-master && python test_se.py
# Out:
# 测试数据集大小: 20
# 类别: ['cardborad', 'cell', 'cigarerre', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     11.jpg                         cardborad       cardborad       ✓
# 2     220.jpg                        cardborad       leftovers       ✗
# 3     tmp291.png                     cell            power_bank      ✗
# 4     tmp663.jpg                     cell            cell            ✓
# 5     tmp6634.jpg                    cell            cell            ✓
# 6     tmp445A.jpg                    cigarerre       cigarerre       ✓
# 7     tmp8027.jpg                    cigarerre       paper           ✗
# 8     tmp7F8D.png                    glass           plastic         ✗
# 9     tmpC6C8.png                    glass           plastic         ✗
# 10    tmp4549.png                    leftovers       leftovers       ✓
# ...

# %%
# !cd garbageClassifier-master && python test_se.py -w model_saved/第一题第二问.pkl --use_se
# Out:
# 权重文件: model_saved/第一题第二问.pkl
# 使用SE注意力: True
# 测试数据集大小: 20
# 类别: ['cardborad', 'cell', 'cigarerre', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     11.jpg                         cardborad       cardborad       ✓
# 2     220.jpg                        cardborad       leftovers       ✗
# 3     tmp291.png                     cell            power_bank      ✗
# 4     tmp663.jpg                     cell            cell            ✓
# 5     tmp6634.jpg                    cell            cell            ✓
# 6     tmp445A.jpg                    cigarerre       cigarerre       ✓
# 7     tmp8027.jpg                    cigarerre       paper           ✗
# 8     tmp7F8D.png                    glass           plastic         ✗
# 9     tmpC6C8.png                    glass           plastic         ✗
# 10    tmp4549.png                    leftovers       leftovers       ✓
# ...

# %%
# !cd garbageClassifier-master && python test_se.py -w model_saved/第一题第二问.pkl
# Out:
# 权重文件: model_saved/第一题第二问.pkl
# 使用SE注意力: False
# 测试数据集大小: 20
# 类别: ['cardborad', 'cell', 'cigarerre', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     11.jpg                         cardborad       power_bank      ✗
# 2     220.jpg                        cardborad       power_bank      ✗
# 3     tmp291.png                     cell            plastic         ✗
# 4     tmp663.jpg                     cell            power_bank      ✗
# 5     tmp6634.jpg                    cell            power_bank      ✗
# 6     tmp445A.jpg                    cigarerre       power_bank      ✗
# 7     tmp8027.jpg                    cigarerre       power_bank      ✗
# 8     tmp7F8D.png                    glass           glass           ✓
# 9     tmpC6C8.png                    glass           power_bank      ✗
# 10    tmp4549.png                    leftovers       plastic         ✗
# ...

# %%
# !cd garbageClassifier-master && python test_se.py -w model_saved/best_model.pkl --use_se
# Out:
# 权重文件: model_saved/best_model.pkl
# 使用SE注意力: True
# 测试数据集大小: 20
# 类别: ['cardborad', 'cell', 'cigarerre', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     11.jpg                         cardborad       cardborad       ✓
# 2     220.jpg                        cardborad       plastic         ✗
# 3     tmp291.png                     cell            cell            ✓
# 4     tmp663.jpg                     cell            plastic         ✗
# 5     tmp6634.jpg                    cell            plastic         ✗
# 6     tmp445A.jpg                    cigarerre       metal           ✗
# 7     tmp8027.jpg                    cigarerre       glass           ✗
# 8     tmp7F8D.png                    glass           plastic         ✗
# 9     tmpC6C8.png                    glass           glass           ✓
# 10    tmp4549.png                    leftovers       leftovers       ✓
# ...

# %%
# !cd garbageClassifier-master && python test_se.py -w model_saved/best_model.pkl
# Out:
# 权重文件: model_saved/best_model.pkl
# 使用SE注意力: False
# 测试数据集大小: 20
# 类别: ['cardborad', 'cell', 'cigarerre', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     11.jpg                         cardborad       cardborad       ✓
# 2     220.jpg                        cardborad       power_bank      ✗
# 3     tmp291.png                     cell            cell            ✓
# 4     tmp663.jpg                     cell            cell            ✓
# 5     tmp6634.jpg                    cell            cell            ✓
# 6     tmp445A.jpg                    cigarerre       cigarerre       ✓
# 7     tmp8027.jpg                    cigarerre       cigarerre       ✓
# 8     tmp7F8D.png                    glass           glass           ✓
# 9     tmpC6C8.png                    glass           power_bank      ✗
# 10    tmp4549.png                    leftovers       leftovers       ✓
# ...

# %%
# !cd garbageClassifier-master && python test_se.py -w model_saved/89.59.pkl
# !cd garbageClassifier-master && python test_se.py -w model_saved/89.59.pkl --use_se
# Out:
# 权重文件: model_saved/89.59.pkl
# 使用SE注意力: False
# 测试数据集大小: 20
# 类别: ['cardborad', 'cell', 'cigarerre', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     11.jpg                         cardborad       leftovers       ✗
# 2     220.jpg                        cardborad       leftovers       ✗
# 3     tmp291.png                     cell            power_bank      ✗
# 4     tmp663.jpg                     cell            cell            ✓
# 5     tmp6634.jpg                    cell            cell            ✓
# 6     tmp445A.jpg                    cigarerre       paper           ✗
# 7     tmp8027.jpg                    cigarerre       paper           ✗
# 8     tmp7F8D.png                    glass           plastic         ✗
# 9     tmpC6C8.png                    glass           power_bank      ✗
# 10    tmp4549.png                    leftovers       leftovers       ✓
# ...

# %%
# !cd garbageClassifier-master && python test_se.py -w model_saved/92.54.pkl
# !cd garbageClassifier-master && python test_se.py -w model_saved/92.54.pkl --use_se
# Out:
# 权重文件: model_saved/92.54.pkl
# 使用SE注意力: False
# 测试数据集大小: 20
# 类别: ['cardborad', 'cell', 'cigarerre', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     11.jpg                         cardborad       metal           ✗
# 2     220.jpg                        cardborad       leftovers       ✗
# 3     tmp291.png                     cell            leftovers       ✗
# 4     tmp663.jpg                     cell            glass           ✗
# 5     tmp6634.jpg                    cell            glass           ✗
# 6     tmp445A.jpg                    cigarerre       glass           ✗
# 7     tmp8027.jpg                    cigarerre       leftovers       ✗
# 8     tmp7F8D.png                    glass           glass           ✓
# 9     tmpC6C8.png                    glass           leftovers       ✗
# 10    tmp4549.png                    leftovers       leftovers       ✓
# ...

# %%
# !cd garbageClassifier-master && python test_se.py -w model_saved/1212.pkl
# Out:
# 权重文件: model_saved/1212.pkl
# 使用SE注意力: False
# 测试数据集大小: 20
# 类别: ['cardborad', 'cell', 'cigarerre', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     11.jpg                         cardborad       cardborad       ✓
# 2     220.jpg                        cardborad       cardborad       ✓
# 3     tmp291.png                     cell            cell            ✓
# 4     tmp663.jpg                     cell            cell            ✓
# 5     tmp6634.jpg                    cell            cell            ✓
# 6     tmp445A.jpg                    cigarerre       cigarerre       ✓
# 7     tmp8027.jpg                    cigarerre       cigarerre       ✓
# 8     tmp7F8D.png                    glass           glass           ✓
# 9     tmpC6C8.png                    glass           glass           ✓
# 10    tmp4549.png                    leftovers       leftovers       ✓
# ...

# %%
# !cd garbageClassifier-master && python test_se.py -w model_saved/1212.pkl --use_se
# Out:
# 权重文件: model_saved/1212.pkl
# 使用SE注意力: True
# 测试数据集大小: 20
# 类别: ['cardborad', 'cell', 'cigarerre', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     11.jpg                         cardborad       metal           ✗
# 2     220.jpg                        cardborad       plastic         ✗
# 3     tmp291.png                     cell            plastic         ✗
# 4     tmp663.jpg                     cell            plastic         ✗
# 5     tmp6634.jpg                    cell            plastic         ✗
# 6     tmp445A.jpg                    cigarerre       metal           ✗
# 7     tmp8027.jpg                    cigarerre       plastic         ✗
# 8     tmp7F8D.png                    glass           plastic         ✗
# 9     tmpC6C8.png                    glass           plastic         ✗
# 10    tmp4549.png                    leftovers       leftovers       ✓
# ...

# %%
# !cd garbageClassifier-master && python test_se.py -w model_saved/best_model_2.pkl
# Out:
# 权重文件: model_saved/best_model_2.pkl
# 使用SE注意力: False
# 测试数据集大小: 20
# 类别: ['cardborad', 'cell', 'cigarerre', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     11.jpg                         cardborad       cardborad       ✓
# 2     220.jpg                        cardborad       cardborad       ✓
# 3     tmp291.png                     cell            cell            ✓
# 4     tmp663.jpg                     cell            cell            ✓
# 5     tmp6634.jpg                    cell            cell            ✓
# 6     tmp445A.jpg                    cigarerre       cigarerre       ✓
# 7     tmp8027.jpg                    cigarerre       cigarerre       ✓
# 8     tmp7F8D.png                    glass           glass           ✓
# 9     tmpC6C8.png                    glass           glass           ✓
# 10    tmp4549.png                    leftovers       leftovers       ✓
# ...

# %%
# !cd garbageClassifier-master && python test_se.py -w model_saved/best_model_2.pkl -d train
# Out:
# 权重文件: model_saved/best_model_2.pkl
# 使用SE注意力: False
# 测试目录: Garbage data/train
# 测试数据集大小: 3278
# 类别: ['cardboard', 'cell', 'cigarette', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     cardboard1.jpg                 cardboard       cardboard       ✓
# 2     cardboard10.jpg                cardboard       cardboard       ✓
# 3     cardboard100.jpg               cardboard       cardboard       ✓
# 305   img_18235.jpg                  cell            cell            ✓
# 306   img_18237.jpg                  cell            cell            ✓
# 307   img_18238.jpg                  cell            cell            ✓
# 555   img_1000.jpg                   cigarette       cigarette       ✓
# 556   img_1001.jpg                   cigarette       cigarette       ✓
# 557   img_1002.jpg                   cigarette       cigarette       ✓
# ...

# %%
# !cd garbageClassifier-master && python test_se.py -w model_saved/best_model_2.pkl -d test
# Out:
# 权重文件: model_saved/best_model_2.pkl
# 使用SE注意力: False
# 测试目录: Garbage data/test
# 测试数据集大小: 845
# 类别: ['cardboard', 'cell', 'cigarette', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     cardboard305.jpg               cardboard       cardboard       ✓
# 2     cardboard306.jpg               cardboard       cardboard       ✓
# 3     cardboard307.jpg               cardboard       cardboard       ✓
# 100   img_18242.jpg                  cell            cell            ✓
# 101   img_18243.jpg                  cell            cell            ✓
# 102   img_18249.jpg                  cell            cell            ✓
# 172   img_1010.jpg                   cigarette       cigarette       ✓
# 173   img_1014.jpg                   cigarette       cigarette       ✓
# 174   img_1015.jpg                   cigarette       cigarette       ✓
# ...

# %%
# !cd garbageClassifier-master && python test_se.py -w model_saved/best_model.pkl -d train
# Out:
# 权重文件: model_saved/best_model.pkl
# 使用SE注意力: False
# 测试目录: Garbage data/train
# 测试数据集大小: 3278
# 类别: ['cardboard', 'cell', 'cigarette', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     cardboard1.jpg                 cardboard       cardboard       ✓
# 2     cardboard10.jpg                cardboard       cardboard       ✓
# 3     cardboard100.jpg               cardboard       cardboard       ✓
# 305   img_18235.jpg                  cell            cell            ✓
# 306   img_18237.jpg                  cell            cell            ✓
# 307   img_18238.jpg                  cell            cell            ✓
# 555   img_1000.jpg                   cigarette       cigarette       ✓
# 556   img_1001.jpg                   cigarette       cigarette       ✓
# 557   img_1002.jpg                   cigarette       cigarette       ✓
# ...

# %%
# !cd garbageClassifier-master && python test_se.py -w model_saved/best_model.pkl -d test
# Out:
# 权重文件: model_saved/best_model.pkl
# 使用SE注意力: False
# 测试目录: Garbage data/test
# 测试数据集大小: 845
# 类别: ['cardboard', 'cell', 'cigarette', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     cardboard305.jpg               cardboard       cardboard       ✓
# 2     cardboard306.jpg               cardboard       cardboard       ✓
# 3     cardboard307.jpg               cardboard       cardboard       ✓
# 100   img_18242.jpg                  cell            cell            ✓
# 101   img_18243.jpg                  cell            cell            ✓
# 102   img_18249.jpg                  cell            cell            ✓
# 172   img_1010.jpg                   cigarette       cigarette       ✓
# 173   img_1014.jpg                   cigarette       cigarette       ✓
# 174   img_1015.jpg                   cigarette       cigarette       ✓
# ...

# %%
# !cd garbageClassifier-master && python test_se.py -w model_saved/best_model.pkl
# Out:
# 权重文件: model_saved/best_model.pkl
# 使用SE注意力: False
# 测试目录: Garbage data/test2
# 测试数据集大小: 20
# 类别: ['cardborad', 'cell', 'cigarerre', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     11.jpg                         cardborad       cardborad       ✓
# 2     220.jpg                        cardborad       power_bank      ✗
# 3     tmp663.jpg                     cell            cell            ✓
# 4     tmp6634.jpg                    cell            cell            ✓
# 5     tmp445A.jpg                    cigarerre       cigarerre       ✓
# 6     tmp8027.jpg                    cigarerre       cigarerre       ✓
# 7     tmp7F8D.png                    glass           glass           ✓
# 8     tmpC6C8.png                    glass           power_bank      ✗
# 9     tmp4549.png                    leftovers       leftovers       ✓
# ...

# %%
# !cd garbageClassifier-master && python test_se.py -w model_saved/best_model_3.pkl
# !cd garbageClassifier-master && python test_se.py -w model_saved/best_model_3.pkl -d train
# !cd garbageClassifier-master && python test_se.py -w model_saved/best_model_3.pkl -d test
# Out:
# 权重文件: model_saved/best_model_3.pkl
# 使用SE注意力: False
# 测试目录: Garbage data/test2
# 测试数据集大小: 20
# 类别: ['cardborad', 'cell', 'cigarerre', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     11.jpg                         cardborad       cardborad       ✓
# 2     220.jpg                        cardborad       cardborad       ✓
# 3     tmp663.jpg                     cell            cell            ✓
# 4     tmp6634.jpg                    cell            cell            ✓
# 5     tmp445A.jpg                    cigarerre       cigarerre       ✓
# 6     tmp8027.jpg                    cigarerre       cigarerre       ✓
# 7     tmp7F8D.png                    glass           glass           ✓
# 8     tmpC6C8.png                    glass           glass           ✓
# 9     tmp4549.png                    leftovers       leftovers       ✓
# ...

# %%
# !cd garbageClassifier-master && python test_se.py -w model_saved/best_model_4.pkl
# !cd garbageClassifier-master && python test_se.py -w model_saved/best_model_4.pkl -d train
# !cd garbageClassifier-master && python test_se.py -w model_saved/best_model_4.pkl -d test
# Out:
# 权重文件: model_saved/best_model_4.pkl
# 使用SE注意力: False
# 测试目录: Garbage data/test2
# 测试数据集大小: 20
# 类别: ['cardborad', 'cell', 'cigarerre', 'glass', 'leftovers', 'metal', 'paper', 'pericarp', 'plastic', 'power_bank']
#
# ...
# 序号    图片名                            真实标签            预测标签            结果
# ...
# 1     11.jpg                         cardborad       cardborad       ✓
# 2     220.jpg                        cardborad       cardborad       ✓
# 3     tmp663.jpg                     cell            cell            ✓
# 4     tmp6634.jpg                    cell            cell            ✓
# 5     tmp445A.jpg                    cigarerre       cigarerre       ✓
# 6     tmp8027.jpg                    cigarerre       cigarerre       ✓
# 7     tmp7F8D.png                    glass           glass           ✓
# 8     tmpC6C8.png                    glass           glass           ✓
# 9     tmp4549.png                    leftovers       leftovers       ✓
# ...
